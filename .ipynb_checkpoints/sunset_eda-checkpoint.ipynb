# %%
import pandas as pd
import requests

# %% [markdown]
# Sunset Data Collection is based on my own personal data and ratings. Throughout the data collection process, I have been in different areas of the US for summer. As a result, each respective location has its own sunset rating and I will use respective weather data for it.

# %%
base_url = "https://api.tomorrow.io/v4/timelines"
api_key = "uGKyJ0FaDdQRmOZgRz9lp8Bww5PmkuPu"
location = 92122
fields = ["temperature", "humidity", "visibility", "epaIndex", "pressureSeaLevel", "pressureSurfaceLevel", "precipitationProbability", "precipitationType", "cloudCover", "cloudBase", "cloudCeiling"]
# output = requests.get('https://api.tomorrow.io/v4/timelines?location=92122&timesteps=1h&units=metric&apikey=uGKyJ0FaDdQRmOZgRz9lp8Bww5PmkuPu')
url = base_url + "?location=" + str(location) + "&fields=" + str(fields)[1:-1].replace("'", "").replace(" ", "") + "&timesteps=1h&units=metric&apikey=" + str(api_key)
print(url)
# Out:
# https://api.tomorrow.io/v4/timelines?location=92122&fields=temperature,humidity,visibility,epaIndex,pressureSeaLevel,pressureSurfaceLevel,precipitationProbability,precipitationType,cloudCover,cloudBase,cloudCeiling&timesteps=1h&units=metric&apikey=uGKyJ0FaDdQRmOZgRz9lp8Bww5PmkuPu

# %%
str(fields)[1:-1].replace("'", "").replace(" ", "")
# Out:
# 'temperature,humidity,visibility,epaIndex,pressureSeaLevel,pressureSurfaceLevel,precipitationProbability,precipitationType,cloudCover,cloudBase,cloudCeiling'

# %%
output = requests.get(url)

output.text
# Out:
# '{"data":{"timelines":[{"timestep":"1h","endTime":"2023-07-02T06:00:00Z","startTime":"2023-06-27T06:00:00Z","intervals":[{"startTime":"2023-06-27T06:00:00Z","values":{"cloudBase":0.17,"cloudCeiling":0.17,"cloudCover":53,"humidity":92,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.81,"pressureSurfaceLevel":1000.69,"temperature":15.31,"visibility":13.61}},{"startTime":"2023-06-27T07:00:00Z","values":{"cloudBase":null,"cloudCeiling":null,"cloudCover":26.32,"humidity":87.05,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.25,"pressureSurfaceLevel":1001.05,"temperature":16.45,"visibility":13.71}},{"startTime":"2023-06-27T08:00:00Z","values":{"cloudBase":0.34,"cloudCeiling":null,"cloudCover":34.84,"humidity":87.84,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.45,"pressureSurfaceLevel":1001.25,"temperature":16.16,"visibility":13.53}},{"startTime":"2023-06-27T09:00:00Z","values":{"cloudBase":0.31,"cloudCeiling":null,"cloudCover":86.7,"humidity":87.69,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.07,"pressureSurfaceLevel":1000.84,"temperature":16.01,"visibility":13.04}},{"startTime":"2023-06-27T10:00:00Z","values":{"cloudBase":0.29,"cloudCeiling":0.26,"cloudCover":99.53,"humidity":87.83,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.12,"pressureSurfaceLevel":1000.87,"temperature":15.83,"visibility":13.21}},{"startTime":"2023-06-27T11:00:00Z","values":{"cloudBase":0.25,"cloudCeiling":null,"cloudCover":86.25,"humidity":87.33,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1011.99,"pressureSurfaceLevel":1000.74,"temperature":15.67,"visibility":13.46}},{"startTime":"2023-06-27T12:00:00Z","values":{"cloudBase":0.25,"cloudCeiling":null,"cloudCover":40.64,"humidity":88.1,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.23,"pressureSurfaceLevel":1000.9,"temperature":15.26,"visibility":13.41}},{"startTime":"2023-06-27T13:00:00Z","values":{"cloudBase":0.22,"cloudCeiling":0.26,"cloudCover":49.13,"humidity":88.52,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.06,"pressureSurfaceLevel":1000.68,"temperature":14.77,"visibility":12.38}},{"startTime":"2023-06-27T14:00:00Z","values":{"cloudBase":0.22,"cloudCeiling":0.26,"cloudCover":95.82,"humidity":87.35,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.28,"pressureSurfaceLevel":1000.97,"temperature":15.33,"visibility":12.65}},{"startTime":"2023-06-27T15:00:00Z","values":{"cloudBase":0.23,"cloudCeiling":0.27,"cloudCover":98.9,"humidity":86.46,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.05,"pressureSurfaceLevel":1000.79,"temperature":15.6,"visibility":13.43}},{"startTime":"2023-06-27T16:00:00Z","values":{"cloudBase":0.27,"cloudCeiling":0.29,"cloudCover":96.29,"humidity":83.96,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1011.96,"pressureSurfaceLevel":1000.77,"temperature":16.28,"visibility":14.85}},{"startTime":"2023-06-27T17:00:00Z","values":{"cloudBase":0.32,"cloudCeiling":null,"cloudCover":50.46,"humidity":79.58,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1012.02,"pressureSurfaceLevel":1001.01,"temperature":17.44,"visibility":16}},{"startTime":"2023-06-27T18:00:00Z","values":{"cloudBase":null,"cloudCeiling":null,"cloudCover":11.29,"humidity":73.58,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1011.84,"pressureSurfaceLevel":1000.99,"temperature":18.72,"visibility":16}},{"startTime":"2023-06-27T19:00:00Z","values":{"cloudBase":null,"cloudCeiling":null,"cloudCover":7.64,"humidity":69.38,"precipitationProbability":0,"precipitationType":0,"pressureSeaLevel":1011.54,"pressureSurfaceLevel":1000.77,"temperature":19.26,"visibility":16}},{"startTime":"2023-06-27T20:00:00Z","values":{"cloudBase":null,"cloudCeiling":null,"cloudCover":11.29,"humidity":67.67,"precipitationP ...
